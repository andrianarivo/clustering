# %% [markdown]
# # Clustering Retail Sales Data
# Customer Shopping Dataset

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('data/customer_shopping_data.csv')
train = dataset[['age', 'price']].copy()
train.head()
# Out:
#    age    price
# 0   28  1500.40
# 1   21  1800.51
# 2   20   300.08
# 3   66  3000.85
# 4   53    60.60

# %%
scaler = StandardScaler().fit(train)
X = scaler.transform(train)

# %%
inertias = []
k_range = range(1, 11)
for k in k_range:
    kmeans=KMeans(n_clusters=k)
    kmeans.fit_predict(X)
    inertias.append(kmeans.inertia_)

plt.figure(figsize=(8, 4))
plt.plot(k_range, inertias, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertias')
plt.xticks(k_range)
plt.show()

# %%
k=3
kmeans=KMeans(n_clusters=k)
y_pred=kmeans.fit_predict(X)

# %%
print(kmeans.cluster_centers_)
train['cluster'] = y_pred
train.head()
# Out:
# [[ 1.83451286e-03  2.57559249e+00]
#  [ 8.76733021e-01 -2.37985599e-01]
#  [-8.65623410e-01 -2.41331713e-01]]
#    age    price  cluster
# 0   28  1500.40        2
# 1   21  1800.51        2
# 2   20   300.08        2
# 3   66  3000.85        0
# 4   53    60.60        1

# %%
cluster_analysis = train.groupby('cluster').agg({
    'price': ['mean', 'count'],
    'age': 'mean'
}).reset_index()
cluster_analysis.columns = ['cluster', 'avg_spent', 'customer_count', 'avg_age']

print("Cluster Analysis Summary:")
display(cluster_analysis)
print(f"Total of customer_count: {cluster_analysis['customer_count'].sum()}")
# Out:
# Cluster Analysis Summary:
#    cluster    avg_spent  customer_count    avg_age
# 0        0  3116.112236            8444  43.393179
# 1        1   466.100556           45219  56.574095
# 2        2   462.119779           45794  30.451413
# Total of customer_count: 99457

# %%
kmeans.inertia_
# Out:
# 68465.55398375567
